# %% [markdown]
# <a href="https://colab.research.google.com/github/shireesha27/demo/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras import layers
from keras.preprocessing.text import Tokenizer
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('imdb_master.csv',encoding='latin-1')
print(df.head())
# Out:
#    Unnamed: 0  type  ... label         file
# 0           0  test  ...   neg      0_2.txt
# 1           1  test  ...   neg  10000_4.txt
# 2           2  test  ...   neg  10001_1.txt
# 3           3  test  ...   neg  10002_3.txt
# 4           4  test  ...   neg  10003_3.txt
#
# [5 rows x 5 columns]

# %%
sentences = df['review'].values
y = df['label'].values
#tokenizing data
tokenizer = Tokenizer(num_words=2000)
tokenizer.fit_on_texts(sentences)
#getting the vocabulary of data
sentences = tokenizer.texts_to_matrix(sentences)

# %%
le = preprocessing.LabelEncoder()
y = le.fit_transform(y)
X_train, X_test, y_train, y_test = train_test_split(sentences, y, test_size=0.25, random_state=1000)
# defining input_dim
input_dim=np.prod(X_train.shape[1:]) 
# Number of features
print(input_dim)
# Out:
# 2000

# %%
model = Sequential()
model.add(layers.Dense(300,input_dim= input_dim, activation='relu'))
model.add(layers.Dense(3, activation='softmax')) 
#changing number of neuron to 3 as we have only two labels Pos and Neg and Sup
#The activation layer is set to softmax as it works best for the multi class classification
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['acc'])
history=model.fit(X_train,y_train, epochs=5, verbose=True, validation_data=(X_test,y_test), batch_size=256)
# Out:
# Epoch 1/5
# 293/293 [==============================] - 6s 22ms/step - loss: 0.8805 - acc: 0.5041 - val_loss: 0.8408 - val_acc: 0.5147
# Epoch 2/5
# 293/293 [==============================] - 6s 21ms/step - loss: 0.7889 - acc: 0.5799 - val_loss: 0.8428 - val_acc: 0.5171
# Epoch 3/5
# 293/293 [==============================] - 6s 21ms/step - loss: 0.6843 - acc: 0.6814 - val_loss: 0.8721 - val_acc: 0.5092
# Epoch 4/5
# 293/293 [==============================] - 6s 21ms/step - loss: 0.4966 - acc: 0.8163 - val_loss: 0.9479 - val_acc: 0.5041
# Epoch 5/5
# 293/293 [==============================] - 6s 21ms/step - loss: 0.2911 - acc: 0.9241 - val_loss: 1.0484 - val_acc: 0.5040

# %%
# Calculating the accuracy of the fitted model on the testing data set.
[test_loss, test_acc] = model.evaluate(X_test, y_test)
print("Evaluation result on Test Data : Loss = {}, accuracy = {}".format(test_loss, test_acc))
print(history.history.keys())
# Out:
# 782/782 [==============================] - 2s 3ms/step - loss: 1.0484 - acc: 0.5040
# Evaluation result on Test Data : Loss = 1.0484070777893066, accuracy = 0.5040000081062317
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
# Analyze by visualizing data
# Summarize history for an accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model accuracy and Loss')
plt.ylabel('accuracy and Loss ')
plt.xlabel('epoch')
plt.legend(['accuracy','val_accuracy','loss','val_loss'], loc='upper left')
plt.show()

# %%
from keras.layers import Embedding, Flatten
from keras.preprocessing.sequence import pad_sequences

sentences = df['review']

# %%
max_review_len= max([len(s.split()) for s in sentences])
vocab_size= len(tokenizer.word_index)+1
sentences = tokenizer.texts_to_sequences(sentences)
padded_docs= pad_sequences(sentences,maxlen=max_review_len)
le = preprocessing.LabelEncoder()
y = le.fit_transform(y)
X_train, X_test, y_train, y_test = train_test_split(padded_docs, y, test_size=0.25, random_state=1000)

model1 = Sequential()
model1.add(Embedding(vocab_size, 50, input_length=max_review_len))
model1.add(Flatten())
model1.add(layers.Dense(300, activation='relu',input_dim=max_review_len))
model1.add(layers.Dense(3, activation='softmax'))
model1.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['acc'])
history1=model1.fit(X_train,y_train, epochs=5, verbose=True, validation_data=(X_test,y_test), batch_size=256)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-2670463233f3> in <module>()
# ----> 1 max_review_len= max([len(s.split()) for s in sentences])
#       2 vocab_size= len(tokenizer.word_index)+1
#       3 sentences = tokenizer.texts_to_sequences(sentences)
#       4 padded_docs= pad_sequences(sentences,maxlen=max_review_len)
#       5 le = preprocessing.LabelEncoder()
#
# <ipython-input-20-2670463233f3> in <listcomp>(.0)
# ----> 1 max_review_len= max([len(s.split()) for s in sentences])
#       2 vocab_size= len(tokenizer.word_index)+1
#       3 sentences = tokenizer.texts_to_sequences(sentences)
#       4 padded_docs= pad_sequences(sentences,maxlen=max_review_len)
#       5 le = preprocessing.LabelEncoder()
#
# AttributeError: 'list' object has no attribute 'split'

# %%
# Analyze by visualizing data
# Summarize history for an accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model accuracy and Loss')
plt.ylabel('accuracy and Loss ')
plt.xlabel('epoch')
plt.legend(['accuracy','val_accuracy','loss','val_loss'], loc='upper left')
plt.show()

# %%
from sklearn.datasets import fetch_20newsgroups
newsgroups_train = fetch_20newsgroups(subset='train', shuffle=True)
sentences = newsgroups_train.data
y = newsgroups_train.target
# Out:
# Downloading 20news dataset. This may take a few minutes.
# Downloading dataset from https://ndownloader.figshare.com/files/5975967 (14 MB)

# %%
max_review_len= max([len(s.split()) for s in sentences])
vocab_size= len(tokenizer.word_index)+1
sentences = tokenizer.texts_to_sequences(sentences)
padded_docs= pad_sequences(sentences,maxlen=max_review_len)
le = preprocessing.LabelEncoder()
y = le.fit_transform(y)
X_train, X_test, y_train, y_test = train_test_split(padded_docs, y, test_size=0.25, random_state=1000)

model2 = Sequential()
model2.add(Embedding(vocab_size, 50, input_length=max_review_len))
model2.add(Flatten())
model2.add(layers.Dense(300, activation='relu',input_dim=max_review_len))
model2.add(layers.Dense(20, activation='softmax'))
model2.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['acc'])
historynew=model2.fit(X_train,y_train, epochs=5, verbose=True, validation_data=(X_test,y_test), batch_size=256)
# Out:
# Epoch 1/5
# 34/34 [==============================] - 245s 7s/step - loss: 9.6028 - acc: 0.0552 - val_loss: 3.2137 - val_acc: 0.0838
# Epoch 2/5
# 34/34 [==============================] - 242s 7s/step - loss: 3.0352 - acc: 0.0645 - val_loss: 2.9774 - val_acc: 0.0774
# Epoch 3/5
# 34/34 [==============================] - 243s 7s/step - loss: 2.9435 - acc: 0.0800 - val_loss: 2.9413 - val_acc: 0.0703
# Epoch 4/5
# 34/34 [==============================] - 242s 7s/step - loss: 2.8852 - acc: 0.0911 - val_loss: 2.8946 - val_acc: 0.1046
# Epoch 5/5
# 34/34 [==============================] - 241s 7s/step - loss: 2.7878 - acc: 0.1182 - val_loss: 2.7896 - val_acc: 0.1262

# %%
# Analyze by visualizing data
# Summarize history for an accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model accuracy and Loss')
plt.ylabel('accuracy and Loss ')
plt.xlabel('epoch')
plt.legend(['accuracy','val_accuracy','loss','val_loss'], loc='upper left')
plt.show()

# %%
# predicting over the 4th sample data
print("Actual Value:",y_test[4],"Predicted Value",model2.predict_classes(X_test[[4],:]))
# Out:
# WARNING:tensorflow:From <ipython-input-26-ccf714f1a4ef>:2: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# Actual Value: 4 Predicted Value [6]
